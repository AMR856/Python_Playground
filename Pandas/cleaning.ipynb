# %%
import pandas as pd

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values = na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# DevType                 Which of the following describe you? Please se...
# YearsCode               Including any education, how many years have y...
# Age1stCode              At what age did you write your first line of c...
# YearsCodePro            How many years have you coded professionally (...
# CareerSat               Overall, how satisfied are you with your caree...
# JobSat                  How satisfied are you with your current job? (...
# MgrIdiot                How confident are you that your manager knows ...
# MgrMoney                Do you believe that you need to be a manager t...
# MgrWant                 Do you want to become a manager yourself in th...
# JobSeek                 Which of the following best describes your cur...
# LastHireDate            When was the last time that you took a job wit...
# LastInt                 In your most recent successful job interview (...
# FizzBuzz                Have you ever been asked to solve FizzBuzz in ...
# JobFactors              Imagine that you are deciding between two job ...
# ResumeUpdate            Think back to the last time you updated your r...
# CurrencySymbol          Which currency do you use day-to-day? If your ...
# CurrencyDesc            Which currency do you use day-to-day? If your ...
# CompTotal               What is your current total compensation (salar...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# ConvertedComp           Salary converted to annual USD salaries using ...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkPlan                          How structured or planned is your work?
# WorkChallenge           Of these options, what are your greatest chall...
# WorkRemote                                How often do you work remotely?
# WorkLoc                                   Where would you prefer to work?
# ImpSyn                  For the specific work you do, and the years of...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# UnitTests               Does your company regularly employ unit tests ...
# PurchaseHow             How does your company make decisions about pur...
# PurchaseWhat            What level of influence do you, personally, ha...
# LanguageWorkedWith      Which of the following programming, scripting,...
# LanguageDesireNextYear  Which of the following programming, scripting,...
# DatabaseWorkedWith      Which of the following database environments h...
# DatabaseDesireNextYear  Which of the following database environments h...
# PlatformWorkedWith      Which of the following platforms have you done...
# PlatformDesireNextYear  Which of the following platforms have you done...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# MiscTechWorkedWith      Which of the following other frameworks, libra...
# MiscTechDesireNextYear  Which of the following other frameworks, libra...
# DevEnviron              Which development environment(s) do you use re...
# OpSys                   What is the primary operating system in which ...
# Containers              How do you use containers (Docker, Open Contai...
# BlockchainOrg           How is your organization thinking about or imp...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BetterLife              Do you think people born today will have a bet...
# ITperson                 Are you the "IT support person" for your family?
# OffOn                         Have you tried turning it off and on again?
# SocialMedia                   What social media site do you use the most?
# Extraversion              Do you prefer online chat or IRL conversations?
# ScreenName                                           What do you call it?
# SOVisit1st              To the best of your memory, when did you first...
# SOVisitFreq             How frequently would you say you visit Stack O...
# SOVisitTo               I visit Stack Overflow to... (check all that a...
# SOFindAnswer            On average, how many times a week do you find ...
# SOTimeSaved             Think back to the last time you solved a codin...
# SOHowMuchTime           About how much time did you save? If you're no...
# SOAccount                           Do you have a Stack Overflow account?
# SOPartFreq              How frequently would you say you participate i...
# SOJobs                  Have you ever used or visited Stack Overflow J...
# EntTeams                Have you ever used Stack Overflow for Enterpri...
# SOComm                  Do you consider yourself a member of the Stack...
# WelcomeChange           Compared to last year, how welcome do you feel...
# SONewContent            Would you like to see any of the following on ...
# Age                     What is your age (in years)? If you prefer not...
# Gender                  Which of the following do you currently identi...
# Trans                                     Do you identify as transgender?
# Sexuality               Which of the following do you currently identi...
# Ethnicity               Which of the following do you identify as? Ple...
# Dependents              Do you have any dependents (e.g., children, el...
# SurveyLength            How do you feel about the length of the survey...
# SurveyEase              How easy or difficult was this survey to compl...

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# df['YearsCode'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#       2 # df['YearsCode'].mean()
#
# File ~/Python_Playground/Pandas/env/lib/python3.10/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/Python_Playground/Pandas/env/lib/python3.10/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File ~/Python_Playground/Pandas/env/lib/python3.10/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~/Python_Playground/Pandas/env/lib/python3.10/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File ~/Python_Playground/Pandas/env/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File ~/Python_Playground/Pandas/env/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/Python_Playground/Pandas/env/lib/python3.10/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#     129     raise ValueError(msg)
#     131 if copy or arr.dtype == object or dtype == object:
#     132     # Explicit copy, or required since NumPy can't view from / to object.
# --> 133     return arr.astype(dtype, copy=True)
#     135 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: 'Less than 1 year'

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
filt = df['YearsCode'] > 50
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 840                    I am a student who is learning to code       No
# 3604        I used to be a developer by profession, but no...      Yes
# 5417        I used to be a developer by profession, but no...      Yes
# 7054                           I am a developer by profession      Yes
# 7488        I used to be a developer by profession, but no...      Yes
# ...                                                       ...      ...
# 87755                          I am a developer by profession       No
# 4625                                                      NaN      Yes
# 50685                                                     NaN       No
# 62177                                                     NaN      Yes
# 86566                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 840                                Once a month or more often
# 3604                               Once a month or more often
# 5417        Less than once a month but more than once per ...
# 7054                               Once a month or more often
# 7488                                  Less than once per year
# ...                                                       ...
# 87755                              Once a month or more often
# 4625                               Once a month or more often
# 50685                              Once a month or more often
# 62177                                 Less than once per year
# 86566       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 840         OSS is, on average, of LOWER quality than prop...
# 3604        OSS is, on average, of HIGHER quality than pro...
# 5417        The quality of OSS and closed source software ...
# 7054        OSS is, on average, of HIGHER quality than pro...
# 7488        OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 87755       OSS is, on average, of HIGHER quality than pro...
# 4625        The quality of OSS and closed source software ...
# 50685       OSS is, on average, of LOWER quality than prop...
# 62177       OSS is, on average, of LOWER quality than prop...
# 86566       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment         Country  \
# Respondent
# 840                                        Employed full-time    Saudi Arabia
# 3604                                                  Retired   United States
# 5417        Independent contractor, freelancer, or self-em...        Cambodia
# 7054                                                  Retired   United States
# 7488                                                  Retired  Czech Republic
# ...                                                       ...             ...
# 87755                                      Employed full-time   United States
# 4625                                                      NaN           Italy
# 50685                                                 Retired           India
# 62177                                      Employed full-time          Poland
# 86566                                                 Retired     Switzerland
#
#                    Student                                            EdLevel  \
# Respondent
# 840         Yes, full-time                                                NaN
# 3604                    No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5417                   NaN          Other doctoral degree (Ph.D, Ed.D., etc.)
# 7054                    No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 7488                    No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...                    ...                                                ...
# 87755                   No          Other doctoral degree (Ph.D, Ed.D., etc.)
# 4625                   NaN                                                NaN
# 50685                  NaN             I never completed any formal education
# 62177                  NaN  Secondary school (e.g. American high school, G...
# 86566                   No  Some college/university study without earning ...
#
#                                                UndergradMajor  \
# Respondent
# 840                                                       NaN
# 3604        Computer science, computer engineering, or sof...
# 5417                                                      NaN
# 7054        Computer science, computer engineering, or sof...
# 7488                                Mathematics or statistics
# ...                                                       ...
# 87755       Another engineering discipline (ex. civil, ele...
# 4625                                                      NaN
# 50685                                                     NaN
# 62177                                                     NaN
# 86566       A humanities discipline (ex. literature, histo...
#
#                                                      EduOther  \
# Respondent
# 840                                                       NaN
# 3604        Taken an online course in programming or softw...
# 5417        Taken an online course in programming or softw...
# 7054        Taken an online course in programming or softw...
# 7488        Taken a part-time in-person course in programm...
# ...                                                       ...
# 87755       Taken an online course in programming or softw...
# 4625                                                      NaN
# 50685                                                     NaN
# 62177                                                     NaN
# 86566       Taken a part-time in-person course in programm...
#
#                              OrgSize  \
# Respondent
# 840                              NaN
# 3604                             NaN
# 5417                             NaN
# 7054                             NaN
# 7488                             NaN
# ...                              ...
# 87755       10,000 or more employees
# 4625                             NaN
# 50685                            NaN
# 62177       10,000 or more employees
# 86566                            NaN
#
#                                                       DevType  YearsCode  \
# Respondent
# 840                                                       NaN       51.0
# 3604                                                      NaN       51.0
# 5417        Academic researcher;Data or business analyst;D...       51.0
# 7054                                                      NaN       51.0
# 7488                                                      NaN       51.0
# ...                                                       ...        ...
# 87755                                                Educator       51.0
# 4625                                                      NaN       51.0
# 50685                                                     NaN       51.0
# 62177                                                     NaN       51.0
# 86566                                                     NaN       51.0
#
#                Age1stCode        YearsCodePro          CareerSat  \
# Respondent
# 840         Older than 85                 NaN                NaN
# 3604                   18  More than 50 years                NaN
# 5417        Older than 85  More than 50 years                NaN
# 7054                   13                  40                NaN
# 7488                   19                  42                NaN
# ...                   ...                 ...                ...
# 87755                  17                  40  Very dissatisfied
# 4625                  NaN                 NaN                NaN
# 50685                  15  More than 50 years                NaN
# 62177       Older than 85  More than 50 years                NaN
# 86566                  17                  22                NaN
#
#                        JobSat            MgrIdiot MgrMoney MgrWant  \
# Respondent
# 840                       NaN                 NaN      NaN     NaN
# 3604                      NaN                 NaN      NaN     NaN
# 5417                      NaN                 NaN      NaN     NaN
# 7054                      NaN                 NaN      NaN     NaN
# 7488                      NaN                 NaN      NaN     NaN
# ...                       ...                 ...      ...     ...
# 87755       Very dissatisfied  Somewhat confident      Yes      No
# 4625                      NaN                 NaN      NaN     NaN
# 50685                     NaN                 NaN      NaN     NaN
# 62177                     NaN  Somewhat confident      Yes     Yes
# 86566                     NaN                 NaN      NaN     NaN
#
#                                                  JobSeek  \
# Respondent
# 840                      I am actively looking for a job
# 3604                                                 NaN
# 5417                                                 NaN
# 7054                                                 NaN
# 7488                                                 NaN
# ...                                                  ...
# 87755       I am not interested in new job opportunities
# 4625                                                 NaN
# 50685                                                NaN
# 62177                                                NaN
# 86566                                                NaN
#
#                                                  LastHireDate LastInt  \
# Respondent
# 840         NA - I am an independent contractor or self em...     NaN
# 3604                                                      NaN     NaN
# 5417                                                      NaN     NaN
# 7054                                                      NaN     NaN
# 7488                                                      NaN     NaN
# ...                                                       ...     ...
# 87755                                           3-4 years ago     NaN
# 4625                                                      NaN     NaN
# 50685                                                     NaN     NaN
# 62177                                                     NaN     NaN
# 86566                                                     NaN     NaN
#
#            FizzBuzz                                         JobFactors  \
# Respondent
# 840             NaN         Opportunities for professional development
# 3604            NaN                                                NaN
# 5417            NaN                                                NaN
# 7054            NaN                                                NaN
# 7488            NaN                                                NaN
# ...             ...                                                ...
# 87755           Yes  Financial performance or funding status of the...
# 4625            NaN                                                NaN
# 50685           NaN                                                NaN
# 62177           NaN                                                NaN
# 86566           NaN                                                NaN
#
#                                                 ResumeUpdate CurrencySymbol  \
# Respondent
# 840                                                      NaN            NaN
# 3604                                                     NaN            NaN
# 5417                                                     NaN            NaN
# 7054                                                     NaN            NaN
# 7488                                                     NaN            NaN
# ...                                                      ...            ...
# 87755       My job status changed (promotion, new job, etc.)            USD
# 4625                                                     NaN            NaN
# 50685                                                    NaN            NaN
# 62177                                                    NaN            NaN
# 86566                                                    NaN            NaN
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 840                          NaN        NaN      NaN            NaN
# 3604                         NaN        NaN      NaN            NaN
# 5417                         NaN        NaN      NaN            NaN
# 7054                         NaN        NaN      NaN            NaN
# 7488                         NaN        NaN      NaN            NaN
# ...                          ...        ...      ...            ...
# 87755       United States dollar   110000.0   Yearly       110000.0
# 4625                         NaN        NaN      NaN            NaN
# 50685                        NaN        NaN      NaN            NaN
# 62177                        NaN        NaN      NaN            NaN
# 86566                        NaN        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 840                 NaN                                                NaN
# 3604                NaN                                                NaN
# 5417                NaN                                                NaN
# 7054                NaN                                                NaN
# 7488                NaN                                                NaN
# ...                 ...                                                ...
# 87755              50.0  There's no schedule or spec; I work on what se...
# 4625                NaN                                                NaN
# 50685               NaN                                                NaN
# 62177               NaN                                                NaN
# 86566               NaN                                                NaN
#
#            WorkChallenge                                         WorkRemote  \
# Respondent
# 840                  NaN                                                NaN
# 3604                 NaN                                                NaN
# 5417                 NaN                                                NaN
# 7054                 NaN                                                NaN
# 7488                 NaN                                                NaN
# ...                  ...                                                ...
# 87755           Meetings  Less than half the time, but at least one day ...
# 4625                 NaN                                                NaN
# 50685                NaN                                                NaN
# 62177                NaN                                                NaN
# 86566                NaN                                                NaN
#
#            WorkLoc             ImpSyn  \
# Respondent
# 840            NaN                NaN
# 3604           NaN                NaN
# 5417           NaN                NaN
# 7054           NaN                NaN
# 7488           NaN                NaN
# ...            ...                ...
# 87755         Home  Far above average
# 4625           NaN                NaN
# 50685          NaN                NaN
# 62177          NaN                NaN
# 86566          NaN                NaN
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 840                                             NaN         NaN
# 3604                                            NaN         NaN
# 5417                                            NaN         NaN
# 7054                                            NaN         NaN
# 7488                                            NaN         NaN
# ...                                             ...         ...
# 87755       Yes, because I see value in code review         2.0
# 4625                                            NaN         NaN
# 50685                                           NaN         NaN
# 62177                                           NaN         NaN
# 86566                                           NaN         NaN
#
#                                 UnitTests  \
# Respondent
# 840                                   NaN
# 3604                                  NaN
# 5417                                  NaN
# 7054                                  NaN
# 7488                                  NaN
# ...                                   ...
# 87755       Yes, it's part of our process
# 4625                                  NaN
# 50685                                 NaN
# 62177                                 NaN
# 86566                                 NaN
#
#                                                   PurchaseHow  \
# Respondent
# 840                                                       NaN
# 3604                                                      NaN
# 5417                                                      NaN
# 7054                                                      NaN
# 7488                                                      NaN
# ...                                                       ...
# 87755       The CTO, CIO, or other management purchase new...
# 4625                                                      NaN
# 50685                                                     NaN
# 62177                                                     NaN
# 86566                                                     NaN
#
#                      PurchaseWhat  \
# Respondent
# 840                           NaN
# 3604                          NaN
# 5417                          NaN
# 7054                          NaN
# 7488                          NaN
# ...                           ...
# 87755       I have some influence
# 4625                          NaN
# 50685                         NaN
# 62177                         NaN
# 86566                         NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 840                                                       NaN
# 3604             Bash/Shell/PowerShell;C;HTML/CSS;Java;Python
# 5417                                                 Assembly
# 7054                             C;C++;Java;JavaScript;Python
# 7488                                Bash/Shell/PowerShell;SQL
# ...                                                       ...
# 87755                                              Java;Scala
# 4625                                                      NaN
# 50685                         C#;HTML/CSS;Java;JavaScript;PHP
# 62177       Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 86566         Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
#
#                                        LanguageDesireNextYear  \
# Respondent
# 840                                                       NaN
# 3604             Bash/Shell/PowerShell;C;HTML/CSS;Java;Python
# 5417                                                 Assembly
# 7054                                                   Python
# 7488                             Bash/Shell/PowerShell;Python
# ...                                                       ...
# 87755                                                   Scala
# 4625                                                      NaN
# 50685                         C#;HTML/CSS;Java;JavaScript;PHP
# 62177       Assembly;Bash/Shell/PowerShell;C;C++;C#;Clojur...
# 86566       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
#
#                                            DatabaseWorkedWith  \
# Respondent
# 840                                                       NaN
# 3604                                                      NaN
# 5417        Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 7054                                                      NaN
# 7488                                                    MySQL
# ...                                                       ...
# 87755                                                     NaN
# 4625                                                      NaN
# 50685                                 MySQL;PostgreSQL;SQLite
# 62177       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 86566                                                     NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 840                                                       NaN
# 3604                                                      NaN
# 5417        Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 7054                                                      NaN
# 7488                                                      NaN
# ...                                                       ...
# 87755                                                     NaN
# 4625                                                      NaN
# 50685                                 MySQL;PostgreSQL;SQLite
# 62177       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 86566                                                     NaN
#
#                             PlatformWorkedWith  \
# Respondent
# 840                                    Android
# 3604                             Android;Linux
# 5417                                   Android
# 7054        Arduino;Linux;Raspberry Pi;Windows
# 7488                                   Windows
# ...                                        ...
# 87755                             Docker;Linux
# 4625                                       NaN
# 50685                          Microsoft Azure
# 62177                                      NaN
# 86566                            Linux;Windows
#
#                                    PlatformDesireNextYear  \
# Respondent
# 840                                               Android
# 3604                                        Android;Linux
# 5417                                              Android
# 7054                   Arduino;Linux;Raspberry Pi;Windows
# 7488                                        Linux;Windows
# ...                                                   ...
# 87755       Google Cloud Platform;Kubernetes;Raspberry Pi
# 4625                                                  NaN
# 50685                                     Microsoft Azure
# 62177                                                 NaN
# 86566                                       Linux;Windows
#
#                                            WebFrameWorkedWith  \
# Respondent
# 840                                                       NaN
# 3604                                                      NaN
# 5417        Angular/Angular.js;ASP.NET;Django;Drupal;Expre...
# 7054                                                      NaN
# 7488                                                      NaN
# ...                                                       ...
# 87755                                                     NaN
# 4625                                                      NaN
# 50685                           ASP.NET;Drupal;jQuery;Laravel
# 62177                                                     NaN
# 86566                                                     NaN
#
#                                        WebFrameDesireNextYear  \
# Respondent
# 840                                                       NaN
# 3604                                                      NaN
# 5417        Angular/Angular.js;ASP.NET;Django;Drupal;Expre...
# 7054                                                      NaN
# 7488                                                      NaN
# ...                                                       ...
# 87755                                                     NaN
# 4625                                                      NaN
# 50685                           ASP.NET;Drupal;jQuery;Laravel
# 62177                                                     NaN
# 86566                                                     NaN
#
#                                            MiscTechWorkedWith  \
# Respondent
# 840                                                 Other(s):
# 3604                                                      NaN
# 5417        Ansible;Apache Spark;Chef;Cordova;CryEngine;Fl...
# 7054                                                      NaN
# 7488                                                     .NET
# ...                                                       ...
# 87755                                            Apache Spark
# 4625                                                      NaN
# 50685                                          .NET;.NET Core
# 62177                                                     NaN
# 86566                                                     NaN
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 840                                                 Other(s):
# 3604                                                      NaN
# 5417        Ansible;Apache Spark;Chef;Cordova;CryEngine;Fl...
# 7054                                                      NaN
# 7488                                                     .NET
# ...                                                       ...
# 87755                                 Apache Spark;TensorFlow
# 4625                                                      NaN
# 50685                                          .NET;.NET Core
# 62177                                                     NaN
# 86566                                                     NaN
#
#                                                    DevEnviron        OpSys  \
# Respondent
# 840                                            Android Studio      Windows
# 3604                                       Android Studio;Vim  Linux-based
# 5417        Android Studio;Atom;Coda;Eclipse;Emacs;Intelli...          NaN
# 7054                                IntelliJ;PyCharm;RubyMine  Linux-based
# 7488        Notepad++;Sublime Text;Visual Studio;Visual St...      Windows
# ...                                                       ...          ...
# 87755                                                IntelliJ        MacOS
# 4625                                                      NaN          NaN
# 50685       Eclipse;Notepad++;PHPStorm;Visual Studio;Visua...      Windows
# 62177       Eclipse;Emacs;Sublime Text;TextMate;Visual Stu...          NaN
# 86566                                                   Emacs      Windows
#
#                                                    Containers  \
# Respondent
# 840                                                       NaN
# 3604                                  I do not use containers
# 5417        Development;Testing;Production;Outside of work...
# 7054                                  I do not use containers
# 7488                                  I do not use containers
# ...                                                       ...
# 87755                                     Development;Testing
# 4625                                  I do not use containers
# 50685                                              Production
# 62177                                 I do not use containers
# 86566                                 I do not use containers
#
#                                                 BlockchainOrg  \
# Respondent
# 840         Accepting Bitcoin or other coins and tokens as...
# 3604                                                      NaN
# 5417                                                      NaN
# 7054                                                      NaN
# 7488                                                      NaN
# ...                                                       ...
# 87755                 Non-currency applications of blockchain
# 4625                                                      NaN
# 50685                                                     NaN
# 62177                 Non-currency applications of blockchain
# 86566                                                     NaN
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 840                                                       NaN        Yes
# 3604                                                      NaN         No
# 5417                                                      NaN        Yes
# 7054        Useful for immutable record keeping outside of...        Yes
# 7488                                                      NaN         No
# ...                                                       ...        ...
# 87755       Useful for immutable record keeping outside of...         No
# 4625                                                      NaN        NaN
# 50685                                           A passing fad         No
# 62177       Useful for immutable record keeping outside of...        Yes
# 86566       Useful for immutable record keeping outside of...         No
#
#                                             ITperson  OffOn  \
# Respondent
# 840                                         Also Yes    NaN
# 3604                                             Yes  What?
# 5417        Fortunately, someone else has that title    Yes
# 7054                                             Yes  What?
# 7488                                             Yes  What?
# ...                                              ...    ...
# 87755                                            Yes    Yes
# 4625                                             NaN  What?
# 50685                                           SIGH  What?
# 62177       Fortunately, someone else has that title  What?
# 86566                                           SIGH    Yes
#
#                          SocialMedia              Extraversion ScreenName  \
# Respondent
# 840                              NaN                       NaN        NaN
# 3604        I don't use social media  In real life (in person)      Login
# 5417                             NaN  In real life (in person)        NaN
# 7054                         Twitter  In real life (in person)      Login
# 7488                        WhatsApp  In real life (in person)        NaN
# ...                              ...                       ...        ...
# 87755                       Facebook  In real life (in person)     UserID
# 4625        I don't use social media  In real life (in person)        NaN
# 50685                      WeChat 微信                   Neither      Login
# 62177                          Hello                       NaN      Login
# 86566                        YouTube  In real life (in person)     Handle
#
#                   SOVisit1st  \
# Respondent
# 840                     2019
# 3604                    2012
# 5417        I don't remember
# 7054                    2013
# 7488                    2014
# ...                      ...
# 87755                   2010
# 4625                    2018
# 50685       I don't remember
# 62177                   2019
# 86566                   2017
#
#                                                   SOVisitFreq  \
# Respondent
# 840                                                       NaN
# 3604                                    Daily or almost daily
# 5417        I have never visited Stack Overflow (before to...
# 7054                                     A few times per week
# 7488                                    Daily or almost daily
# ...                                                       ...
# 87755                                    A few times per week
# 4625                                                      NaN
# 50685                                  Multiple times per day
# 62177       I have never visited Stack Overflow (before to...
# 86566                         A few times per month or weekly
#
#                                                     SOVisitTo  \
# Respondent
# 840                                                       NaN
# 3604        Find answers to specific questions;Learn how t...
# 5417        Find answers to specific questions;Learn how t...
# 7054                       Find answers to specific questions
# 7488        Find answers to specific questions;Learn how t...
# ...                                                       ...
# 87755       Find answers to specific questions;Contribute ...
# 4625                                                      NaN
# 50685       Find answers to specific questions;Learn how t...
# 62177                                                     NaN
# 86566       Find answers to specific questions;Contribute ...
#
#                            SOFindAnswer                         SOTimeSaved  \
# Respondent
# 840                                 NaN                                 NaN
# 3604                 1-2 times per week      Stack Overflow was much faster
# 5417            Less than once per week  The other resource was much faster
# 7054                 1-2 times per week      Stack Overflow was much faster
# 7488                 3-5 times per week      Stack Overflow was much faster
# ...                                 ...                                 ...
# 87755           Less than once per week  Stack Overflow was slightly faster
# 4625            Less than once per week  The other resource was much faster
# 50685       More than 10 times per week  The other resource was much faster
# 62177           Less than once per week      Stack Overflow was much faster
# 86566           Less than once per week      Stack Overflow was much faster
#
#             SOHowMuchTime                  SOAccount  \
# Respondent
# 840                   NaN                        NaN
# 3604        11-30 minutes  Not sure / can't remember
# 5417         0-10 minutes                        NaN
# 7054        11-30 minutes                        Yes
# 7488        11-30 minutes                        Yes
# ...                   ...                        ...
# 87755       31-60 minutes                        Yes
# 4625          60+ minutes  Not sure / can't remember
# 50685        0-10 minutes  Not sure / can't remember
# 62177         60+ minutes                        NaN
# 86566         60+ minutes                        Yes
#
#                                      SOPartFreq  \
# Respondent
# 840                                         NaN
# 3604                                        NaN
# 5417                                        NaN
# 7054        Less than once per month or monthly
# 7488                      Daily or almost daily
# ...                                         ...
# 87755                      A few times per week
# 4625                                        NaN
# 50685                                       NaN
# 62177                                       NaN
# 86566       Less than once per month or monthly
#
#                                                        SOJobs  \
# Respondent
# 840                                                       NaN
# 3604        No, I knew that Stack Overflow had a job board...
# 5417                                                      Yes
# 7054        No, I didn't know that Stack Overflow had a jo...
# 7488        No, I knew that Stack Overflow had a job board...
# ...                                                       ...
# 87755       No, I knew that Stack Overflow had a job board...
# 4625                                                      NaN
# 50685                                                     Yes
# 62177       No, I didn't know that Stack Overflow had a jo...
# 86566       No, I didn't know that Stack Overflow had a jo...
#
#                                                      EntTeams  \
# Respondent
# 840                                                       NaN
# 3604                      No, and I don't know what those are
# 5417                                                      Yes
# 7054        No, I've heard of them, but I am not part of a...
# 7488        No, I've heard of them, but I am not part of a...
# ...                                                       ...
# 87755                     No, and I don't know what those are
# 4625        No, I've heard of them, but I am not part of a...
# 50685                                                     Yes
# 62177                                                     Yes
# 86566                     No, and I don't know what those are
#
#                      SOComm  \
# Respondent
# 840                     NaN
# 3604         No, not really
# 5417        Yes, definitely
# 7054          Yes, somewhat
# 7488        Yes, definitely
# ...                     ...
# 87755       Yes, definitely
# 4625          Yes, somewhat
# 50685              Not sure
# 62177       Yes, definitely
# 86566               Neutral
#
#                                                 WelcomeChange  \
# Respondent
# 840                                                       NaN
# 3604                  Just as welcome now as I felt last year
# 5417                  Just as welcome now as I felt last year
# 7054                  Just as welcome now as I felt last year
# 7488                  Just as welcome now as I felt last year
# ...                                                       ...
# 87755                   A lot more welcome now than last year
# 4625        Not applicable - I did not use Stack Overflow ...
# 50685                   A lot less welcome now than last year
# 62177       Not applicable - I did not use Stack Overflow ...
# 86566                 Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 840                                                       NaN   NaN    NaN
# 3604        Tech articles written by other developers;Cour...   NaN    Man
# 5417        Tech articles written by other developers;Indu...   NaN    Man
# 7054        Tech articles written by other developers;Tech...   NaN    NaN
# 7488                Tech articles written by other developers   NaN    Man
# ...                                                       ...   ...    ...
# 87755               Tech articles written by other developers  68.0    Man
# 4625                                                      NaN   NaN    NaN
# 50685       Tech articles written by other developers;Indu...   NaN  Woman
# 62177            Courses on technologies you're interested in   NaN    NaN
# 86566       Tech articles written by other developers;Cour...  74.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 840          NaN                      NaN
# 3604          No  Straight / Heterosexual
# 5417         NaN                      NaN
# 7054         NaN                      NaN
# 7488          No  Straight / Heterosexual
# ...          ...                      ...
# 87755         No  Straight / Heterosexual
# 4625         NaN                      NaN
# 50685         No  Straight / Heterosexual
# 62177        NaN                      NaN
# 86566         No                      NaN
#
#                                                     Ethnicity Dependents  \
# Respondent
# 840                                                       NaN        Yes
# 3604                             White or of European descent         No
# 5417        Black or of African descent;East Asian;Hispani...        Yes
# 7054                                                      NaN        NaN
# 7488                             White or of European descent         No
# ...                                                       ...        ...
# 87755                            White or of European descent        Yes
# 4625                                                      NaN        NaN
# 50685                                                     NaN        NaN
# 62177                            White or of European descent        NaN
# 86566                            White or of European descent         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 840                           NaN                         NaN
# 3604        Appropriate in length                        Easy
# 5417        Appropriate in length                        Easy
# 7054        Appropriate in length                        Easy
# 7488        Appropriate in length  Neither easy nor difficult
# ...                           ...                         ...
# 87755                    Too long  Neither easy nor difficult
# 4625                          NaN  Neither easy nor difficult
# 50685       Appropriate in length  Neither easy nor difficult
# 62177       Appropriate in length                   Difficult
# 86566       Appropriate in length                        Easy
#
# [126 rows x 84 columns]

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0
